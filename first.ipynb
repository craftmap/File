# %%
import numpy
from matplotlib import pyplot
myarray = numpy.linspace(0, 5, 10)
print(myarray)
# Out:
# [0.         0.55555556 1.11111111 1.66666667 2.22222222 2.77777778
#  3.33333333 3.88888889 4.44444444 5.        ]

# %% [markdown]
# myarray = numpy.linspace(3, 10, 4)

# %%
import numpy
from matplotlib import pyplot
myarray = numpy.linspace(3, 4, 10)
print(myarray)
# Out:
# [3.         3.11111111 3.22222222 3.33333333 3.44444444 3.55555556
#  3.66666667 3.77777778 3.88888889 4.        ]

# %%
ar = numpy.array([1, 2, 3, 4, 5])
ar
# Out:
# array([1, 2, 3, 4, 5])

# %%
ar[0]
# Out:
# 1

# %%
ar[1], ar[2]
# Out:
# (2, 3)

# %%
myarray
# Out:
# array([3.        , 3.11111111, 3.22222222, 3.33333333, 3.44444444,
#        3.55555556, 3.66666667, 3.77777778, 3.88888889, 4.        ])

# %%
N = 50
x_start, x_end = -1.0, 2.0
y_start, y_end = -2.0, 2.0
x = numpy.linspace(x_start, x_end, N)
y = numpy.linspace(y_start, y_end, N)
print("x = ", x)
print("y = ", y)
X, Y = numpy.meshgrid(x, y)
# Out:
# x =  [-1.         -0.93877551 -0.87755102 -0.81632653 -0.75510204 -0.69387755
#  -0.63265306 -0.57142857 -0.51020408 -0.44897959 -0.3877551  -0.32653061
#  -0.26530612 -0.20408163 -0.14285714 -0.08163265 -0.02040816  0.04081633
#   0.10204082  0.16326531  0.2244898   0.28571429  0.34693878  0.40816327
#   0.46938776  0.53061224  0.59183673  0.65306122  0.71428571  0.7755102
#   0.83673469  0.89795918  0.95918367  1.02040816  1.08163265  1.14285714
#   1.20408163  1.26530612  1.32653061  1.3877551   1.44897959  1.51020408
#   1.57142857  1.63265306  1.69387755  1.75510204  1.81632653  1.87755102
#   1.93877551  2.        ]
# y =  [-2.         -1.91836735 -1.83673469 -1.75510204 -1.67346939 -1.59183673
#  -1.51020408 -1.42857143 -1.34693878 -1.26530612 -1.18367347 -1.10204082
#  -1.02040816 -0.93877551 -0.85714286 -0.7755102  -0.69387755 -0.6122449
#  -0.53061224 -0.44897959 -0.36734694 -0.28571429 -0.20408163 -0.12244898
# ...

# %%
X, Y
# Out:
# (array([[-1.        , -0.93877551, -0.87755102, ...,  1.87755102,
#           1.93877551,  2.        ],
#         [-1.        , -0.93877551, -0.87755102, ...,  1.87755102,
#           1.93877551,  2.        ],
#         [-1.        , -0.93877551, -0.87755102, ...,  1.87755102,
#           1.93877551,  2.        ],
#         ...,
#         [-1.        , -0.93877551, -0.87755102, ...,  1.87755102,
#           1.93877551,  2.        ],
#         [-1.        , -0.93877551, -0.87755102, ...,  1.87755102,
#           1.93877551,  2.        ],
#         [-1.        , -0.93877551, -0.87755102, ...,  1.87755102,
#           1.93877551,  2.        ]]),
#  array([[-2.        , -2.        , -2.        , ..., -2.        ,
#          -2.        , -2.        ],
#         [-1.91836735, -1.91836735, -1.91836735, ..., -1.91836735,
#          -1.91836735, -1.91836735],
#         [-1.83673469, -1.83673469, -1.83673469, ..., -1.83673469,
#          -1.83673469, -1.83673469],
#         ...,
# ...

# %%
# %matplotlib inline

# рисуем сетку из узлов
size = 10
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('x', fontsize=29) # подпись осей
pyplot.ylabel('y', fontsize=29)
pyplot.xlim(x_start, x_end) # деления на оси
pyplot.ylim(y_start, y_end)
pyplot.scatter(X, Y, s=10, color='m', marker='o', linewidth=0)

# %%
from numpy import math
strength_source = 5
x_source, y_source = 0.0, 0.0
u_source = strength_source/(2*math.pi)*(X-x_source)/((X-x_source)**2 + \
                                                     (Y-y_source)**2)
v_source = strength_source/(2*math.pi)*(Y-y_source)/((X-x_source)**2 + \
                                                     (Y-y_source)**2)

# %%
# рисуем линии тока
size = 10
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('x', fontsize=19)
pyplot.ylabel('y', fontsize=19)
pyplot.xlim(x_start, x_end)
pyplot.ylim(y_start, y_end)
pyplot.streamplot(X, Y, u_source, v_source, density=2, \
                  linewidth=1, arrowsize=2, arrowstyle='->')
pyplot.scatter(x_source, y_source, color='#CD2305', s=80, marker='o', \
               linewidth=0);

# %%
strength_sink = -5.0                     # интенсивность стока
x_sink, y_sink = 1.3, -1.0                # положение стока

# вычисление скорости в узлах расчётной сетки
u_sink = strength_sink/(2*math.pi) * (X-x_sink)/((X-x_sink)**2 + \
                                                 (Y-y_sink)**2)
v_sink = strength_sink/(2*math.pi) * (Y-y_sink)/((X-x_sink)**2 + \
                                                 (Y-y_sink)**2)

# %%
# рисуем линии тока
size = 10
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.xlim(x_start, x_end)
pyplot.ylim(y_start, y_end)
pyplot.streamplot(X, Y, u_sink, v_sink, density=2, linewidth=1, \
                  arrowsize=2, arrowstyle='->')
pyplot.scatter(x_sink, y_sink, color='#CD2305', s=80, marker='o', \
               linewidth=0);

# %%
# вычисление скорости для системы источник-сток 
# путем сложения элементарных решений
u_pair = u_source + u_sink
v_pair = v_source + v_sink

# рисуем линии тока системы источник-сток
size = 10
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.xlim(x_start, x_end)
pyplot.ylim(y_start, y_end)
pyplot.streamplot(X, Y, u_pair, v_pair, density=2.0, linewidth=1, \
                  arrowsize=2, arrowstyle='->')
pyplot.scatter([x_source, x_sink], [y_source, y_sink], \
            color='#CD2305', s=80, marker='o', linewidth=0);

# %%
3 + 2j
# Out:
# (3+2j)

# %%
a = 3
b = 3
z = a + b * 1j
print('z = ', z)
print('The type of the variable is ', type(z))
# Out:
# z =  (3+3j)
# The type of the variable is  <class 'complex'>

# %%
1.4*e**(5.32*j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-522e1508edea> in <module>
# ----> 1 1.4*e**(5.32*j)
#
# NameError: name 'e' is not defined

# %%
import math
import cmath
#Владимир Анатольевич Анимица

# %%
import numpy
from matplotlib import pyplot
xs = -1
xe = 2
ys = -2
ye = 2
step = 0.1
xn = int((xe - xs) / step) + 1
yn = int((ye - ys) / step) + 1

x = numpy.linspace(xs, xe, xn)
y = numpy.linspace(ys, ye, yn)
X, Y = numpy.meshgrid(x, y)
f = open('Data.txt', 'r')
vel_y  = [     ]
vel_x = [    ]

for i in range(xn*yn):
    str = f.readline().split()
    vel_x.append(float(str[0]))
    vel_y.append(float(str[1]))
    
vel_y = numpy.reshape(vel_y,(31,41))


vel_x = numpy.reshape(vel_x,(31,41))

# %%
N = 8
m = N + 1
n = N + 2
plate_beg_x = 0.0
plate_end_x = 1.0
plate_beg_y = 0.0
plate_end_y = 0.0
x_control = [plate_beg_x + (plate_end_x - plate_beg_x) * (i + 0.75) / float(N) for i in range(N)]
y_control = [plate_beg_y + (plate_end_y - plate_beg_y) * (i + 0.75) / float(N)for i in range(N)]
pyplot.figure(figsize = (30,20))
pyplot.quiver(X, Y, numpy.transpose(vel_x), numpy.transpose(vel_y))
pyplot.plot(x_control, y_control, linewidth=10)
